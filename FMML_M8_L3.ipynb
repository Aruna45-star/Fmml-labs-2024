# %% [markdown]
# <a href="https://colab.research.google.com/github/Aruna45-star/Fmml-labs-2024/blob/main/FMML_M8_L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-17 11:41:00--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   132MB/s    in 0.5s
#
# 2025-03-17 11:41:03 (132 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 493  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 19  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4881   1610.01476v1  In this paper, we study the Temporal Differenc...    cs
# 27791  1704.05624v1  In this work, based on the local phase informa...    cs
# 29380  1709.02476v1  While fine-grained object recognition is an im...    cs
# 35295  cs/0308030v1  We introduce the topic of learning in multiage...    cs
# 4761    1311.3959v4  We present algorithms to effectively represent...    cs
# ...             ...                                                ...   ...
# 39571  1609.04855v2  Microtask crowdsourcing is increasingly critic...    cs
# 8907   1703.01720v4  To be able to interact better with humans, it ...    cs
# 21820   1206.1846v2  A mixture of Gaussians fit to a single curved ...  stat
# 36735   1404.5528v1  In this paper with the aid of genetic algorith...    cs
# 22503  1610.04751v1  In this paper, we consider clustering data tha...  stat
#
#                                                    title  year  \
# 4881   $\ell_1$ Regularized Gradient Temporal-Differe...  2016
# 27791  FSITM: A Feature Similarity Index For Tone-Map...  2017
# 29380  Fine-grained Recognition in the Wild: A Multi-...  2017
# 35295  Learning in Multiagent Systems: An Introductio...  2003
# 4761   Clustering Markov Decision Processes For Conti...  2013
# ...                                                  ...   ...
# 39571  A Glimpse Far into the Future: Understanding L...  2016
# 8907   Sound-Word2Vec: Learning Word Representations ...  2017
# 21820   Warped Mixtures for Nonparametric Cluster Shapes  2012
# 36735  Hybrid Genetic Algorithm for Cloud Computing A...  2014
# 22503  Unsupervised clustering under the Union of Pol...  2016
#
#                                                 keywords
# 4881   [difference, approximation, algorithms, approx...
# 27791  [information, objective, similarity, associate...
# 29380  [recognition, important, accurately, supervise...
# 35295  [introduce, multiagent, introduction, equilibr...
# 4761   [algorithms, effectively, represent, processes...
# ...                                                  ...
# 39571  [microtask, crowdsourcing, increasingly, extre...
# 8907   [understand, perception, embeddings, similarit...
# 21820  [gaussians, appropriate, clusterings, introduc...
# 36735  [algorithm, scheduling, considers, balancing, ...
# 22503  [clustering, polyhedral, polyhedral, subspaces...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4881     [difference, approximation, algorithms, approx...
# 27791    [information, objective, similarity, associate...
# 29380    [recognition, important, accurately, supervise...
# 35295    [introduce, multiagent, introduction, equilibr...
# 4761     [algorithms, effectively, represent, processes...
#                                ...
# 9039     [representation, distribution, individual, coe...
# 21590    [addresses, inferring, multivariate, regressiv...
# 22483    [hamiltonian, algorithm, generates, proposals,...
# 37869    [functional, relevance, modelling, biological,...
# 37879    [regularization, procedures, attractive, selec...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8692 words.
# Out of those 4523 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ef791581-142b-46a4-9626-fd6447384194" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef791581-142b-46a4-9626-fd6447384194")) {                    Plotly.newPlot(                        "ef791581-142b-46a4-9626-fd6447384194",                        [{"x":["overfitting","developing","experiments","attentions","computationally","successfully","addressed","approximation","numerical","particular","regularization","development","difficulty","difference","performance","algorithms","techniques","attracted","regularized","significant","investigate","convergence","available","properties","thresholding","expensive","combining","outperforms","similarity","calculated","associated","information","databases","objective","supervised","attribute","attributes","recognition","important","infeasible","adaptation","categories","consisting","challenging","overcoming","benchmarked","annotated","annotations","simplistic","additional","accurately","including","equilibrium","replicator","fictitious","perspective","introduce","dominance","remaining","challenges","strategies","multiagent","summarize","introduced","engineering","theoretic","introduction","evolutionary","clustering","algorithm","measuring","effectively","processes","surveillance","continual","counteracts","optimally","convergent","reinforcement","framework","generating","necessary","contributions","principled","represent","selection","application","represented","correspond","predominant","magnitude","constraints","composition","construction","modelling","components","preference","inference","preferences","compositional","knowledge","constituent","functional","restrictions","ecological","translates","constraint","incorporation","interacting","satisfaction","repositories","mechanism","mathematical","described","describing","automated","efficient","crowdsourcing","efficiently","applications","aggregation","posterior","dynamically","synthetic","ambiguity","crowdsourced","technique","different","comparisons","considerable","reliability","experimental","desirable","comparison","evaluations","transformations","convexity","illustrated","conversion","mathematically","eliminate","developed","structures","wasserstein","introducing","formulation","segmentation","geometric","representations","variational","alternating","deformations","combination","statistical","performed","variations","simplifying","invariance","practical","dimensional","initialization","equivalent","relaxation","optimization","transport","approaches","polynomial","theoretical","mathematics","impressive","considered","interaction","essentially","underlying","independent","functions","approximating","conditions","graphical","guarantees","exception","partition","correlation","approximations","statistics","threshold","fundamental","semantics","embedding","improvements","contextual","continuous","carefully","consistent","alignment","inferring","questions","linguistic","generated","substantial"],"y":[13,53,598,6,88,75,28,114,95,277,85,127,42,66,878,567,391,22,53,233,144,110,290,216,25,79,128,268,153,34,101,672,64,178,185,39,63,367,356,6,81,56,46,259,7,5,74,56,2,124,48,236,13,3,1,63,304,8,26,103,107,4,16,137,60,46,25,65,138,841,37,113,77,29,3,1,12,11,127,559,97,80,46,34,112,157,255,72,28,5,55,134,32,62,61,103,33,234,37,25,361,10,40,20,3,6,91,9,15,18,3,126,52,64,22,99,400,16,149,430,28,39,34,117,21,7,239,708,37,40,29,366,45,131,54,41,12,18,16,17,12,196,131,5,53,91,205,69,226,56,26,13,149,160,135,77,5,15,136,147,24,65,29,302,12,486,58,141,12,24,122,77,22,118,116,214,13,140,52,54,5,22,68,46,66,35,90,95,100,111,45,113,30,73,48,24,67,65,180,57],"type":"bar"},{"x":["overfitting","developing","experiments","attentions","computationally"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4523,), (4523, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Implementation</span> <span style=''>of</span> <span style=''>Hand</span> <span style='background-color:rgba(0, 255, 0, 0.5493562231759658);'>Detection</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Techniques</span> <span style=''>for</span> <span style=''>Human</span> <span style=''>Computer</span> <span style='background-color:rgba(0, 255, 0, 0.3508771929824562);'>Interaction</span> <br/><br/><span style=''>The</span> <span style=''>computer</span> <span style=''>industry</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developing</span> <span style=''>at</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>pace</span> <span style=''>With</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.5301204819277109);'>development</span> <span style=''>almost</span> <span style=''>all</span> <span style=''>of</span> <span style=''>the</span> <span style=''>fields</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.6190476190476191);'>computers</span> <span style=''>have</span> <span style=''>advanced</span> <span style=''>in</span> <span style=''>the</span> <span style=''>past</span> <span style=''>couple</span> <span style=''>of</span> <span style=''>decades</span> <span style=''>But</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.7313432835820897);'>technology</span> <span style=''>is</span> <span style=''>being</span> <span style=''>used</span> <span style=''>for</span> <span style=''>human</span> <span style=''>computer</span> <span style='background-color:rgba(0, 255, 0, 0.3508771929824562);'>interaction</span> <span style=''>that</span> <span style=''>was</span> <span style=''>used</span> <span style=''>in</span> <span style=''>1970s</span> <span style=''>Even</span> <span style=''>today</span> <span style=''>the</span> <span style=''>same</span> <span style=''>type</span> <span style=''>of</span> <span style=''>keyboard</span> <span style=''>and</span> <span style=''>mouse</span> <span style=''>is</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.30434782608695654);'>interacting</span> <span style=''>with</span> <span style=''>computer</span> <span style=''>systems</span> <span style=''>With</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>boom</span> <span style=''>in</span> <span style=''>the</span> <span style=''>mobile</span> <span style=''>segment</span> <span style=''>touchscreens</span> <span style=''>have</span> <span style=''>become</span> <span style=''>popular</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3508771929824562);'>interaction</span> <span style=''>with</span> <span style=''>cell</span> <span style=''>phones</span> <span style=''>But</span> <span style=''>these</span> <span style=''>touchscreens</span> <span style=''>are</span> <span style=''>rarely</span> <span style=''>used</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditional</span> <span style=''>systems</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>tries</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>human</span> <span style=''>computer</span> <span style='background-color:rgba(0, 255, 0, 0.3508771929824562);'>interaction</span> <span style=''>using</span> <span style=''>the</span> <span style=''>users</span> <span style=''>hand</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>both</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditional</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributionally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Ambiguous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Techniques</span> <span style=''>in</span> <span style=''>Batch</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretically</span> <span style=''>grounded</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>function</span> <span style=''>for</span> <span style=''>batch</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>informed</span> <span style=''>by</span> <span style=''>insights</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributionally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ambiguous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>function</span> <span style=''>is</span> <span style=''>a</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>Expected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Improvement</span> <span style=''>function</span> <span style=''>which</span> <span style=''>requires</span> <span style=''>a</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style=''>over</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>piecewise</span> <span style=''>affine</span> <span style=''>function</span> <span style=''>and</span> <span style=''>is</span> <span style=''>computed</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluating</span> <span style=''>instead</span> <span style=''>the</span> <span style=''>best</span> <span style=''>case</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style=''>over</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>with</span> <span style=''>the</span> <span style=''>same</span> <span style=''>mean</span> <span style=''>and</span> <span style=''>variance</span> <span style=''>as</span> <span style=''>the</span> <span style=''>original</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>Unlike</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>Expected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Improvement</span> <span style=''>our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>function</span> <span style=''>avoids</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>integrations</span> <span style=''>entirely</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>computed</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Weighted</span> <span style=''>Last</span> <span style=''>Step</span> <span style=''>Min</span> <span style=''>Max</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>with</span> <span style=''>Improved</span> <span style=''>Sub</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Logarithmic</span> <span style=''>Regret</span> <br/><br/><span style=''>In</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>function</span> <span style=''>from</span> <span style=''>some</span> <span style=''>class</span> <span style=''>with</span> <span style=''>a</span> <span style=''>quantity</span> <span style=''>called</span> <span style=''>regret</span> <span style=''>Forster</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>last</span> <span style=''>step</span> <span style=''>min</span> <span style=''>max</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>was</span> <span style=''>somewhat</span> <span style=''>simpler</span> <span style=''>than</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>of</span> <span style=''>Vovk</span> <span style=''>yet</span> <span style=''>with</span> <span style=''>the</span> <span style=''>same</span> <span style=''>regret</span> <span style=''>In</span> <span style=''>fact</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>he</span> <span style=''>analyzed</span> <span style=''>assumed</span> <span style=''>that</span> <span style=''>the</span> <span style=''>choices</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363637);'>adversary</span> <span style=''>are</span> <span style=''>bounded</span> <span style=''>yielding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>artificially</span> <span style=''>only</span> <span style=''>the</span> <span style=''>two</span> <span style=''>extreme</span> <span style=''>cases</span> <span style=''>We</span> <span style=''>fix</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>weighing</span> <span style=''>the</span> <span style=''>examples</span> <span style=''>in</span> <span style=''>such</span> <span style=''>a</span> <span style=''>way</span> <span style=''>that</span> <span style=''>the</span> <span style=''>min</span> <span style=''>max</span> <span style=''>problem</span> <span style=''>will</span> <span style=''>be</span> <span style=''>well</span> <span style=''>defined</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>analysis</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>logarithmic</span> <span style=''>regret</span> <span style=''>that</span> <span style=''>may</span> <span style=''>have</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiplicative</span> <span style=''>factor</span> <span style=''>than</span> <span style=''>both</span> <span style=''>bounds</span> <span style=''>of</span> <span style=''>Forster</span> <span style=''>and</span> <span style=''>Vovk</span> <span style=''>We</span> <span style=''>also</span> <span style=''>derive</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>risk</span> <span style=''>analysis</span> <span style=''>approach</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>security</span> <span style=''>settings</span> <span style=''>are</span> <span style=''>usually</span> <span style=''>contemplated</span> <span style=''>as</span> <span style=''>confrontations</span> <span style=''>in</span> <span style=''>which</span> <span style=''>one</span> <span style=''>or</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversaries</span> <span style=''>try</span> <span style=''>to</span> <span style=''>fool</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>benefit</span> <span style=''>Most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>have</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>game</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>ideas</span> <span style=''>with</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>common</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>which</span> <span style=''>are</span> <span style=''>actually</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>realistic</span> <span style=''>in</span> <span style=''>security</span> <span style=''>domains</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>such</span> <span style=''>problem</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>risk</span> <span style=''>analysis</span> <span style=''>which</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> <span style=''>with</span> <span style=''>several</span> <span style=''>examples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computational</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>issues</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discussed</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10071428571428571)
# 	architecture (0.07857142857142857)
# 	automatic (0.07428571428571429)
# 	knowledge (0.12892857142857142)
# 	information (0.24)
# 	segmentation (0.07321428571428572)
# 	different (0.25285714285714284)
# 	detection (0.12892857142857142)
# 	convolutional (0.1275)
# 	recognition (0.13107142857142856)
#
# Some Statistics words are:
# 	stochastic (0.1275)
# 	statistical (0.1475)
# 	variables (0.1365)
# 	algorithm (0.3965)
# 	theoretical (0.151)
# 	distribution (0.1765)
# 	inference (0.1925)
# 	estimation (0.1765)
# 	dimensional (0.1905)
# 	regression (0.187)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="923042fd-5e1f-443f-a0d6-adf704e31a7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("923042fd-5e1f-443f-a0d6-adf704e31a7e")) {                    Plotly.newPlot(                        "923042fd-5e1f-443f-a0d6-adf704e31a7e",                        [{"x":["overfitting","developing","experiments","attentions","computationally","successfully","addressed","approximation","numerical","particular","regularization","development","difficulty","difference","performance","algorithms","techniques","attracted","regularized","significant","investigate","convergence","available","properties","thresholding","expensive","combining","outperforms","similarity","calculated","associated","information","databases","objective","supervised","attribute","attributes","recognition","important","infeasible","adaptation","categories","consisting","challenging","overcoming","benchmarked","annotated","annotations","simplistic","additional","accurately","including","equilibrium","replicator","fictitious","perspective","introduce","dominance","remaining","challenges","strategies","multiagent","summarize","introduced","engineering","theoretic","introduction","evolutionary","clustering","algorithm","measuring","effectively","processes","surveillance","continual","counteracts","optimally","convergent","reinforcement","framework","generating","necessary","contributions","principled","represent","selection","application","represented","correspond","predominant","magnitude","constraints","composition","construction","modelling","components","preference","inference","preferences","compositional","knowledge","constituent","functional","restrictions","ecological","translates","constraint","incorporation","interacting","satisfaction","repositories","mechanism","mathematical","described","describing","automated","efficient","crowdsourcing","efficiently","applications","aggregation","posterior","dynamically","synthetic","ambiguity","crowdsourced","technique","different","comparisons","considerable","reliability","experimental","desirable","comparison","evaluations","transformations","convexity","illustrated","conversion","mathematically","eliminate","developed","structures","wasserstein","introducing","formulation","segmentation","geometric","representations","variational","alternating","deformations","combination","statistical","performed","variations","simplifying","invariance","practical","dimensional","initialization","equivalent","relaxation","optimization","transport","approaches","polynomial","theoretical","mathematics","impressive","considered","interaction","essentially","underlying","independent","functions","approximating","conditions","graphical","guarantees","exception","partition","correlation","approximations","statistics","threshold","fundamental","semantics","embedding","improvements","contextual","continuous","carefully","consistent","alignment","inferring","questions","linguistic","generated","substantial","recovering","demonstrate","neighborhoods","effective","occurrence","generative","relationships","leveraging","observation","operations","embeddings","maximally","character","prerequisite","candidates","evaluated","detection","identified","minimizing","estimated","probabilities","multilingual","corresponding","significantly","competitive","eliminated","detecting","automatically","outperform","classifier","competition","integrate","performing","structural","invariances","symmetries","simulations","structure","usefulness","algebraic","incorporating","invariant","underdetermined","independence","contributes","procedure","conditional","distribution","interpolates","deterministic","bottleneck","distributions","intuitive","boundaries","preferred" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	attacking
# 	subgradients
# 	physionet
# 	promotions
# 	kontorovich
# 	exponents
# 	mcallester
# 	announced
# 	individualized
# 	advertisement
# 	suffering
# 	initializing
# 	heteroskedastic
# 	nonparanormal
# 	suboptimality
# 	observables
# 	fibrillation
# 	affirmative
# 	prominently
# 	polymorphisms
# Some words which never appear in Statistics papers:
# 	benchmarked
# 	replicator
# 	ecological
# 	prerequisite
# 	aspiration
# 	metaheuristics
# 	eigenproblem
# 	infrequently
# 	repetitive
# 	occlusions
# 	sentiments
# 	capitalizes
# 	deformation
# 	distractors
# 	initiated
# 	discriminability
# 	arithmetical
# 	computability
# 	polarities
# 	judgement

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.074747102050856e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
